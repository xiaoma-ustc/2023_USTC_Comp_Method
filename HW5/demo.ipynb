# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_csv("./result0.csv", names=["f1","f2","f3","f4"])

# %%
df1
# Out:
#           f1         f2         f3          f4
# 0  -0.254241  -6.864490 -60.739800 -175.849000
# 1   0.203803   4.128540  27.204500   58.669600
# 2   0.252530   5.151810  34.367300   75.382900
# 3  -0.244121  -3.787900 -19.270900  -31.893700
# 4   0.095455   1.305730   6.197250   10.553300
# 5  -0.082897  -0.834491  -2.363640   -0.861222
# 6  -0.309266  -2.871810  -8.475590   -6.973170
# 7   0.908460   4.434550   6.137120    2.768640
# 8  -0.889575  -0.959557   0.743018    0.970600
# 9   0.203139  -0.959557   0.743018    0.970600
# 10  0.445017  -1.685190   1.468650    0.728722
# 11 -0.738108   5.413560 -12.728900   10.193700
# 12  0.747415  -7.956150  27.380300  -29.915400
# 13 -0.339953   5.092270 -24.813400   39.676200
# 14 -0.111902   1.671510  -7.709600   11.169800
# 15  0.079663  -1.776660  12.979400  -30.208200
# 16  0.163651  -3.540430  25.325800  -59.016400
# 17 -0.319969   8.066460 -67.529300  188.597000
# 18  0.354323 -10.139400  96.323700 -302.962000
# ...

# %%
x0 = np.linspace(-9, -8, 100)
x1 = np.linspace(-8, -7, 100)
x2 = np.linspace(-7, -6, 100)
x3 = np.linspace(-6, -5, 100)
x4 = np.linspace(-5, -4, 100)
x5 = np.linspace(-4, -3, 100)
x6 = np.linspace(-3, -2, 100)
x7 = np.linspace(-2, -1, 100)
x8 = np.linspace(-1, -0, 100)
x9 = np.linspace(0, 1, 100)
x10 = np.linspace(1, 2, 100)
x11 = np.linspace(2, 3, 100)
x12 = np.linspace(3, 4, 100)
x13 = np.linspace(4, 5, 100)
x14 = np.linspace(5, 6, 100)
x15 = np.linspace(6, 7, 100)
x16 = np.linspace(7, 8, 100)
x17 = np.linspace(8, 9, 100)
x18 = np.linspace(9, 10, 100)
x19 = np.linspace(10, 11, 100)

# %%
plt.plot(x0,df1['f1'][0] * (x0 ** 3) + df1['f2'][0] * (x0 ** 2) + df1['f3'][0] * x0 + df1['f4'][0])
plt.plot(x1,df1['f1'][1] * (x1 ** 3) + df1['f2'][1] * (x1 ** 2) + df1['f3'][1] * x1 + df1['f4'][1])
plt.plot(x2,df1['f1'][2] * (x2 ** 3) + df1['f2'][2] * (x2 ** 2) + df1['f3'][2] * x2 + df1['f4'][2])
plt.plot(x3,df1['f1'][3] * (x3 ** 3) + df1['f2'][3] * (x3 ** 2) + df1['f3'][3] * x3 + df1['f4'][3])
plt.plot(x4,df1['f1'][4] * (x4 ** 3) + df1['f2'][4] * (x4 ** 2) + df1['f3'][4] * x4 + df1['f4'][4])
plt.plot(x5,df1['f1'][5] * (x5 ** 3) + df1['f2'][5] * (x5 ** 2) + df1['f3'][5] * x5 + df1['f4'][5])
plt.plot(x6,df1['f1'][6] * (x6 ** 3) + df1['f2'][6] * (x6 ** 2) + df1['f3'][6] * x6 + df1['f4'][6])
plt.plot(x7,df1['f1'][7] * (x7 ** 3) + df1['f2'][7] * (x7 ** 2) + df1['f3'][7] * x7 + df1['f4'][7])
plt.plot(x8,df1['f1'][8] * (x8 ** 3) + df1['f2'][8] * (x8 ** 2) + df1['f3'][8] * x8 + df1['f4'][8])
plt.plot(x9,df1['f1'][9] * (x9 ** 3) + df1['f2'][9] * (x9 ** 2) + df1['f3'][9] * x9 + df1['f4'][9])
plt.plot(x10,df1['f1'][10] * (x10 ** 3) + df1['f2'][10] * (x10 ** 2) + df1['f3'][10] * x10 + df1['f4'][10])
plt.plot(x11,df1['f1'][11] * (x11 ** 3) + df1['f2'][11] * (x11 ** 2) + df1['f3'][11] * x11 + df1['f4'][11])
plt.plot(x12,df1['f1'][12] * (x12 ** 3) + df1['f2'][12] * (x12 ** 2) + df1['f3'][12] * x12 + df1['f4'][12])
plt.plot(x13,df1['f1'][13] * (x13 ** 3) + df1['f2'][13] * (x13 ** 2) + df1['f3'][13] * x13 + df1['f4'][13])
plt.plot(x14,df1['f1'][14] * (x14 ** 3) + df1['f2'][14] * (x14 ** 2) + df1['f3'][14] * x14 + df1['f4'][14])
plt.plot(x15,df1['f1'][15] * (x15 ** 3) + df1['f2'][15] * (x15 ** 2) + df1['f3'][15] * x15 + df1['f4'][15])
plt.plot(x16,df1['f1'][16] * (x16 ** 3) + df1['f2'][16] * (x16 ** 2) + df1['f3'][16] * x16 + df1['f4'][16])
plt.plot(x17,df1['f1'][17] * (x17 ** 3) + df1['f2'][17] * (x17 ** 2) + df1['f3'][17] * x17 + df1['f4'][17])
plt.plot(x18,df1['f1'][18] * (x18 ** 3) + df1['f2'][18] * (x18 ** 2) + df1['f3'][18] * x18 + df1['f4'][18])
plt.plot(x19,df1['f1'][19] * (x19 ** 3) + df1['f2'][19] * (x19 ** 2) + df1['f3'][19] * x19 + df1['f4'][19])

# %%
df2 = pd.read_csv("./result1.csv", names=["f1","f2","f3","f4"])

# %%
df2
# Out:
#            f1         f2         f3         f4
# 0   -0.254626  -6.874910 -60.833200 -176.12600
# 1    0.205731   4.173670  27.555500   59.57680
# 2    0.245201   5.002530  33.357500   73.11480
# 3   -0.216734  -3.312300 -16.531500  -26.66320
# 4   -0.006764  -0.162739  -0.783675   -0.41684
# 5    0.298589   3.501490  13.873200   19.12570
# 6   -1.732990 -14.782700 -40.979400  -35.72690
# 7    6.221880  32.946500  54.479000   27.91200
# 8  -11.690100 -20.789500   0.743018   10.00000
# 9   11.003700 -20.789500   0.743018   10.00000
# 10  -4.868400  26.826700 -46.873200   25.87210
# 11   0.685617  -6.497360  19.775000  -18.56010
# 12   0.365929  -3.620170  11.143400   -9.92847
# 13  -0.237734   3.623790 -17.832500   28.70600
# 14  -0.139292   2.147160 -10.449300   16.40070
# 15   0.087002  -1.926130  13.990400  -32.47870
# 16   0.161685  -3.494480  24.968900  -58.09520
# 17  -0.319443   8.052580 -67.407600  188.24200
# 18   0.354185 -10.135400  96.283800 -302.83200
# ...

# %%
plt.plot(x0,df2['f1'][0] * (x0 ** 3) + df2['f2'][0] * (x0 ** 2) + df2['f3'][0] * x0 + df2['f4'][0])
plt.plot(x1,df2['f1'][1] * (x1 ** 3) + df2['f2'][1] * (x1 ** 2) + df2['f3'][1] * x1 + df2['f4'][1])
plt.plot(x2,df2['f1'][2] * (x2 ** 3) + df2['f2'][2] * (x2 ** 2) + df2['f3'][2] * x2 + df2['f4'][2])
plt.plot(x3,df2['f1'][3] * (x3 ** 3) + df2['f2'][3] * (x3 ** 2) + df2['f3'][3] * x3 + df2['f4'][3])
plt.plot(x4,df2['f1'][4] * (x4 ** 3) + df2['f2'][4] * (x4 ** 2) + df2['f3'][4] * x4 + df2['f4'][4])
plt.plot(x5,df2['f1'][5] * (x5 ** 3) + df2['f2'][5] * (x5 ** 2) + df2['f3'][5] * x5 + df2['f4'][5])
plt.plot(x6,df2['f1'][6] * (x6 ** 3) + df2['f2'][6] * (x6 ** 2) + df2['f3'][6] * x6 + df2['f4'][6])
plt.plot(x7,df2['f1'][7] * (x7 ** 3) + df2['f2'][7] * (x7 ** 2) + df2['f3'][7] * x7 + df2['f4'][7])
plt.plot(x8,df2['f1'][8] * (x8 ** 3) + df2['f2'][8] * (x8 ** 2) + df2['f3'][8] * x8 + df2['f4'][8])
plt.plot(x9,df2['f1'][9] * (x9 ** 3) + df2['f2'][9] * (x9 ** 2) + df2['f3'][9] * x9 + df2['f4'][9])
plt.plot(x10,df2['f1'][10] * (x10 ** 3) + df2['f2'][10] * (x10 ** 2) + df2['f3'][10] * x10 + df2['f4'][10])
plt.plot(x11,df2['f1'][11] * (x11 ** 3) + df2['f2'][11] * (x11 ** 2) + df2['f3'][11] * x11 + df2['f4'][11])
plt.plot(x12,df2['f1'][12] * (x12 ** 3) + df2['f2'][12] * (x12 ** 2) + df2['f3'][12] * x12 + df2['f4'][12])
plt.plot(x13,df2['f1'][13] * (x13 ** 3) + df2['f2'][13] * (x13 ** 2) + df2['f3'][13] * x13 + df2['f4'][13])
plt.plot(x14,df2['f1'][14] * (x14 ** 3) + df2['f2'][14] * (x14 ** 2) + df2['f3'][14] * x14 + df2['f4'][14])
plt.plot(x15,df2['f1'][15] * (x15 ** 3) + df2['f2'][15] * (x15 ** 2) + df2['f3'][15] * x15 + df2['f4'][15])
plt.plot(x16,df2['f1'][16] * (x16 ** 3) + df2['f2'][16] * (x16 ** 2) + df2['f3'][16] * x16 + df2['f4'][16])
plt.plot(x17,df2['f1'][17] * (x17 ** 3) + df2['f2'][17] * (x17 ** 2) + df2['f3'][17] * x17 + df2['f4'][17])
plt.plot(x18,df2['f1'][18] * (x18 ** 3) + df2['f2'][18] * (x18 ** 2) + df2['f3'][18] * x18 + df2['f4'][18])
plt.plot(x19,df2['f1'][19] * (x19 ** 3) + df2['f2'][19] * (x19 ** 2) + df2['f3'][19] * x19 + df2['f4'][19])

# %%
plt.plot(x0,df1['f1'][0] * (x0 ** 3) + df1['f2'][0] * (x0 ** 2) + df1['f3'][0] * x0 + df1['f4'][0])
plt.plot(x1,df1['f1'][1] * (x1 ** 3) + df1['f2'][1] * (x1 ** 2) + df1['f3'][1] * x1 + df1['f4'][1])
plt.plot(x2,df1['f1'][2] * (x2 ** 3) + df1['f2'][2] * (x2 ** 2) + df1['f3'][2] * x2 + df1['f4'][2])
plt.plot(x3,df1['f1'][3] * (x3 ** 3) + df1['f2'][3] * (x3 ** 2) + df1['f3'][3] * x3 + df1['f4'][3])
plt.plot(x4,df1['f1'][4] * (x4 ** 3) + df1['f2'][4] * (x4 ** 2) + df1['f3'][4] * x4 + df1['f4'][4])
plt.plot(x5,df1['f1'][5] * (x5 ** 3) + df1['f2'][5] * (x5 ** 2) + df1['f3'][5] * x5 + df1['f4'][5])
plt.plot(x6,df1['f1'][6] * (x6 ** 3) + df1['f2'][6] * (x6 ** 2) + df1['f3'][6] * x6 + df1['f4'][6])
plt.plot(x7,df1['f1'][7] * (x7 ** 3) + df1['f2'][7] * (x7 ** 2) + df1['f3'][7] * x7 + df1['f4'][7])
plt.plot(x8,df1['f1'][8] * (x8 ** 3) + df1['f2'][8] * (x8 ** 2) + df1['f3'][8] * x8 + df1['f4'][8])
plt.plot(x9,df1['f1'][9] * (x9 ** 3) + df1['f2'][9] * (x9 ** 2) + df1['f3'][9] * x9 + df1['f4'][9])
plt.plot(x10,df1['f1'][10] * (x10 ** 3) + df1['f2'][10] * (x10 ** 2) + df1['f3'][10] * x10 + df1['f4'][10])
plt.plot(x11,df1['f1'][11] * (x11 ** 3) + df1['f2'][11] * (x11 ** 2) + df1['f3'][11] * x11 + df1['f4'][11])
plt.plot(x12,df1['f1'][12] * (x12 ** 3) + df1['f2'][12] * (x12 ** 2) + df1['f3'][12] * x12 + df1['f4'][12])
plt.plot(x13,df1['f1'][13] * (x13 ** 3) + df1['f2'][13] * (x13 ** 2) + df1['f3'][13] * x13 + df1['f4'][13])
plt.plot(x14,df1['f1'][14] * (x14 ** 3) + df1['f2'][14] * (x14 ** 2) + df1['f3'][14] * x14 + df1['f4'][14])
plt.plot(x15,df1['f1'][15] * (x15 ** 3) + df1['f2'][15] * (x15 ** 2) + df1['f3'][15] * x15 + df1['f4'][15])
plt.plot(x16,df1['f1'][16] * (x16 ** 3) + df1['f2'][16] * (x16 ** 2) + df1['f3'][16] * x16 + df1['f4'][16])
plt.plot(x17,df1['f1'][17] * (x17 ** 3) + df1['f2'][17] * (x17 ** 2) + df1['f3'][17] * x17 + df1['f4'][17])
plt.plot(x18,df1['f1'][18] * (x18 ** 3) + df1['f2'][18] * (x18 ** 2) + df1['f3'][18] * x18 + df1['f4'][18])
plt.plot(x19,df1['f1'][19] * (x19 ** 3) + df1['f2'][19] * (x19 ** 2) + df1['f3'][19] * x19 + df1['f4'][19])
plt.plot(x0,df2['f1'][0] * (x0 ** 3) + df2['f2'][0] * (x0 ** 2) + df2['f3'][0] * x0 + df2['f4'][0])
plt.plot(x1,df2['f1'][1] * (x1 ** 3) + df2['f2'][1] * (x1 ** 2) + df2['f3'][1] * x1 + df2['f4'][1])
plt.plot(x2,df2['f1'][2] * (x2 ** 3) + df2['f2'][2] * (x2 ** 2) + df2['f3'][2] * x2 + df2['f4'][2])
plt.plot(x3,df2['f1'][3] * (x3 ** 3) + df2['f2'][3] * (x3 ** 2) + df2['f3'][3] * x3 + df2['f4'][3])
plt.plot(x4,df2['f1'][4] * (x4 ** 3) + df2['f2'][4] * (x4 ** 2) + df2['f3'][4] * x4 + df2['f4'][4])
plt.plot(x5,df2['f1'][5] * (x5 ** 3) + df2['f2'][5] * (x5 ** 2) + df2['f3'][5] * x5 + df2['f4'][5])
plt.plot(x6,df2['f1'][6] * (x6 ** 3) + df2['f2'][6] * (x6 ** 2) + df2['f3'][6] * x6 + df2['f4'][6])
plt.plot(x7,df2['f1'][7] * (x7 ** 3) + df2['f2'][7] * (x7 ** 2) + df2['f3'][7] * x7 + df2['f4'][7])
plt.plot(x8,df2['f1'][8] * (x8 ** 3) + df2['f2'][8] * (x8 ** 2) + df2['f3'][8] * x8 + df2['f4'][8])
plt.plot(x9,df2['f1'][9] * (x9 ** 3) + df2['f2'][9] * (x9 ** 2) + df2['f3'][9] * x9 + df2['f4'][9])
plt.plot(x10,df2['f1'][10] * (x10 ** 3) + df2['f2'][10] * (x10 ** 2) + df2['f3'][10] * x10 + df2['f4'][10])
plt.plot(x11,df2['f1'][11] * (x11 ** 3) + df2['f2'][11] * (x11 ** 2) + df2['f3'][11] * x11 + df2['f4'][11])
plt.plot(x12,df2['f1'][12] * (x12 ** 3) + df2['f2'][12] * (x12 ** 2) + df2['f3'][12] * x12 + df2['f4'][12])
plt.plot(x13,df2['f1'][13] * (x13 ** 3) + df2['f2'][13] * (x13 ** 2) + df2['f3'][13] * x13 + df2['f4'][13])
plt.plot(x14,df2['f1'][14] * (x14 ** 3) + df2['f2'][14] * (x14 ** 2) + df2['f3'][14] * x14 + df2['f4'][14])
plt.plot(x15,df2['f1'][15] * (x15 ** 3) + df2['f2'][15] * (x15 ** 2) + df2['f3'][15] * x15 + df2['f4'][15])
plt.plot(x16,df2['f1'][16] * (x16 ** 3) + df2['f2'][16] * (x16 ** 2) + df2['f3'][16] * x16 + df2['f4'][16])
plt.plot(x17,df2['f1'][17] * (x17 ** 3) + df2['f2'][17] * (x17 ** 2) + df2['f3'][17] * x17 + df2['f4'][17])
plt.plot(x18,df2['f1'][18] * (x18 ** 3) + df2['f2'][18] * (x18 ** 2) + df2['f3'][18] * x18 + df2['f4'][18])
plt.plot(x19,df2['f1'][19] * (x19 ** 3) + df2['f2'][19] * (x19 ** 2) + df2['f3'][19] * x19 + df2['f4'][19])
